# %% [markdown]
# <a href="https://colab.research.google.com/github/kelszn/German-Cars-EDA-Prediction/blob/main/Project_CoachBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 26916057 Udoye Chidubem Mac-Donald


#**************************************************     SPORT Center    ********************************************************
import random

class User:
    def __init__(self, name, height, weight):
        """
        Initialize a user object with the given name, height and weight.
        """
        self.name = name # Assign the input 'name' to the object's name attribute
        self.height = height # Assign the input 'height' to the object's height attribute
        self.weight = weight # Assign the input 'weight' to the object's weight attribute
        self.plan = None # Initialize the user's exercise plan as None
        self.water_intake = 0 # Initialize the user's water intake as 0
        self.progress = {'push_ups': 0, 'lifting': 0, 'stretching': 0, 'yoga': 0}
        # Initialize the user's progress as a dictionary with each exercise and their reps as 0

    def calculate_bmi(self):
        """
        Calculate the user's BMI using the given height and weight.
        """
        bmi = self.weight / (self.height ** 2) # Calculates the bmi using the weight and height attributes
        return bmi

    def set_exercise_plan(self, plan):
        """
        Set the user's exercise plan.
        """
        self.plan = plan # Assigns the input 'plan' to the object's plan attribute

    def track_progress(self):
        """
        Track the user's progress across all exercises.
        """
        progress = 0 # Initialize the progress as 0
        for exercise, reps in self.progress.items():
            progress += reps # Iterate through the progress dictionary and sum the reps for each exercise
        return progress




    def get_motivation(self):
        #List of quotes
        motivational_quotes = [
            "The pain you feel today will be the strength you feel tomorrow.",
            "You don't have to be great to start, but you have to start to be great.",
            "The best time to plant a tree was 20 years ago. The second best time is now.",
            "If you want something you've never had, you must be willing to do something you've never done.",
            "The difference between try and triumph is just a little umph!",
            "Believe you can and you're halfway there.",
            "Train like a beast, look like a beauty.",
            "The only bad workout is the one that didn't happen.",
            "You can't pour from an empty cup. Take care of yourself first.",
            "The only place where success comes before work is in the dictionary."
        ]


        print("\nWelcome to your exercise plan!")
        print("1. Push ups")
        print("2. Lifting")
        print("3. Stretching")
        print("4. Yoga")

        try:
            choice = int(input("What section would you like to start with? (Enter a number):"))
            if choice == 1:
                push_ups = int(input("How many push ups do you want to do today?"))
                print("Start with push ups! Remember, consistency is key.")
                print(f"{push_ups} push ups? You got this!")
                print("Don't forget to drink water!")

                push_ups_done = int(input("How many push ups have you done?"))
                push_ups_percentage = (push_ups_done / push_ups) * 100
                print(
                    f"You have completed {push_ups_done} out of {push_ups} push ups. That's {push_ups_percentage}%.")
                print("Great job! Keep it up!")

            elif choice == 2:
                lifting = int(input("How many lifting do you want to do today?"))
                print("Start with lifting! Remember, consistency is key.")
                print(f"{lifting} lifting? You got this!")
                print("Don't forget to drink water!")

                lifting_done = int(input("How many lifting have you done?"))
                lifting_percentage = (lifting_done / lifting) * 100
                print(
                    f"You have completed {lifting_done} out of {lifting} lifting. That's {lifting_percentage}%.")
                print("Great job! Keep it up!")

            elif choice == 3:
                stretching = int(input("How many stretching do you want to do today?"))
                print("Start with stretching! Remember, consistency is key.")
                print(f"{stretching} stretching? You got this!")
                print("Don't forget to drink water!")

                stretching_done = int(input("How many stretching have you done?"))
                stretching_percentage = (stretching_done / stretching) * 100
                print(
                    f"You have completed {stretching_done} out of {stretching} stretching. That's {stretching_percentage}%.")
                print("Great job! Keep it up!")

            elif choice == 4:
                yoga = int(input("How many yoga do you want to do today?"))
                print("Start with yoga! Remember, consistency is key.")
                print(f"{yoga} yoga? You got this!")
                print("Don't forget to drink water!")

                yoga_done = int(input("How many yoga have you done?"))
                yoga_percentage = (yoga_done / yoga) * 100
                print(f"You have completed {yoga_done} out of {yoga} yoga. That's {yoga_percentage}%.")
                print("Great job! Keep it up!")
                print("Remember to take breaks and listen to your body.")
                print("And don't forget to stretch after your yoga practice.")
            else:
                print("Invalid input. Please enter a number between 1 and 4.")
                # return
        except ValueError:
                print("Invalid input. Please enter a number.")
        quote = random.choice(motivational_quotes)
        print(f"\n\tMotivational quote of the day!\n{quote}")

        quote = random.choice(motivational_quotes)
        print(quote)
        return

    def set_water_intake(self, water_intake):
        self.water_intake = water_intake

    def get_water_intake(self):
        return self.water_intake


class ExerciseSchedule:
    def __init__(self):
        self.schedule = {} # Initialize an empty dictionary to store schedule

    def add_exercise(self, exercise, sets, reps):
        self.schedule[exercise] = (sets, reps) # Add an exercise to the schedule with the given number of sets and reps

    def get_schedule(self):
        return self.schedule # Return the current schedule

    def update_schedule(self, exercise, sets, reps):
        if exercise in self.schedule:
            self.schedule[exercise] = (sets, reps) # Update an existing exercise in the schedule with the new number of sets and reps
        else:
            print(f"{exercise} not found in schedule.") # If exercise is not in the schedule, print error message

    def remove_exercise(self, exercise):
        if exercise in self.schedule:
            del self.schedule[exercise] # Remove an exercise from the schedule
        else:
            print(f"{exercise} not found in schedule.") # If exercise is not in the schedule, print error message



class ExercisePlan:
    def __init__(self, name):
        self.name = name # Initialize the name of the exercise plan
        self.schedule = None

    def set_exercise_schedule(self, schedule):
        self.schedule = schedule # Set the exercise schedule

    def get_exercise_schedule(self):
        return self.schedule # Return the current exercise schedule

    def get_exercise_info(self):
        # Code to get information about the exercises in the schedule
        exercise_info = None
        return exercise_info

    def get_calories_burned(self):
        # Code to calculate the number of calories burned during the exercise schedule
        calories_burned = 0
        return calories_burned

    def get_equipment_info(self):
        # Code to get information about the equipment needed for the exercises in the schedule
        equipment_info = None
        return equipment_info



class Exercise:
    def __init__(self, name):
        self.name = name # Initialize the name of the exercise
        self.info = None # Initialize the info of the exercise
        self.calories_burned = 0 # Initialize the number of calories burned during the exercise
        self.equipment_info = None # Initialize the equipment info of the exercise

    def set_info(self, info):
        self.info = info # Set the info of the exercise

    def get_info(self):
        return self.info # Return the info of the exercise

    def set_calories_burned(self, calories_burned):
        self.calories_burned = calories_burned # Set the number of calories burned during the exercise

    def get_calories_burned(self):
        return self.calories_burned # Return the number of calories burned during the exercise

    def set_equipment_info(self, equipment_info):
        self.equipment_info = equipment_info # Set the equipment info of the exercise

    def get_equipment_info(self):
        return self.equipment_info # Return the equipment info of the exercise


def main():
    while True:
        try:
            name = input("What's your name? Welcome to Sport Center: ")
            height = float(input("Please enter your height in meters: "))
            weight = float(input("Please enter your weight in kg: "))
            user = User(name, height, weight)
            print("Your body mass index is:", user.calculate_bmi())
            print("To reduce weight, you need to stay in shape.")
            break
        except ValueError:
            print("Invalid input. Please enter a valid number for height and weight.")
    while True:
        try:
            print("\nWelcome to your exercise plan!")
            print("1. Push ups")
            print("2. Lifting")
            print("3. Stretching")
            print("4. Yoga")
            choice = int(input("What section would you like to start with? (Enter a number):"))
            if choice == 1:
                push_ups = int(input("How many push ups do you want to do today?"))
                print("Start with push ups! Remember, consistency is key.")
                print(f"{push_ups} push ups? You got this!")
                print("Don't forget to drink water!")
                push_ups_done = int(input("How many push ups have you done?"))
                push_ups_percentage = (push_ups_done / push_ups) * 100
                print(f"You have completed {push_ups_done} out of {push_ups} push ups. That's {push_ups_percentage}%.")
                print("Great job! Keep it up!")
                user.progress['push_ups'] = push_ups_done
                break
            elif choice == 2:
                lifting = int(input("How many lifting do you want to do today?"))
                print("Start with lifting! Remember, consistency is key.")
                print(f"{lifting} lifting? You got this!")
                print("Don't forget to drink water!")
                lifting_done = int(input("How many lifting have you done?"))
                lifting_percentage = (lifting_done / lifting) * 100
                print(f"You have completed {lifting_done} out of {lifting} lifting. That's {lifting_percentage}%.")
                print("Great job! Keep it up!")
                user.progress['lifting'] = lifting_done
                break
            elif choice == 3:
                stretching = int(input("How many stretching do you want to do today?"))
                print("Start with stretching! Remember, consistency is key.")
                print(f"{stretching} stretching? You got this!")
                print("Don't forget to drink water!")
                stretching_done = int(input("How many stretching have you done?"))
                stretching_percentage = (stretching_done / stretching) * 100
                print(f"You have completed {stretching_done} out of {stretching} stretching. That's {stretching_percentage}%.")
                print("Great job! Keep it up!")
                user.progress['stretching'] = stretching_done
                break
            elif choice == 4:
                yoga = int(input("How many yoga do you want to do today?"))
                print("Start with yoga! Remember, consistency is key.")
                print(f"{yoga} yoga? You got this!")
                print("Don't forget to drink water!")
                yoga_done = int(input("How many yoga have you done?"))
                yoga_percentage = (yoga_done / yoga) * 100
                print(f"You have completed {yoga_done} out of {yoga} yoga. That's {yoga_percentage}%.")
                print("Great job! Keep it up!")
                user.progress['yoga'] = yoga_done
                break
            else:
                print("Invalid choice. Please enter a number between 1 and 4.")
        except ValueError:
            print("Invalid input. Please enter a valid number for the number of reps.")
    user.set_exercise_plan(user.progress)
    print("\nMotivational quote of the day!")
    print(user.get_motivation())
    print("Your exercise plan: ", user.plan)
    print("Your progress: ", user.track_progress())

    if __name__ == "__main__":

        main()
